# %%
import os
import csv 

electiondatafile = os.path.join('election_data_short.csv')
file_to_output = os.path.join('analysis.txt')

total_votes_count = 0 

candidate_list = []
candidate_votes_dict = {}
candidate_winner = ""
candidate_winner_vote_count = 0 


with open(electiondatafile, 'r') as electiondata:
    #split the data on commas
    csvreader = csv.reader(electiondata, delimiter=',')
    header = next(csvreader)
    print(header)
    
    for row in csvreader:
        total_votes_count = total_votes_count + 1
        print(float(total_votes_count))
        print(row)
        candidate_row = row[2]
        print(candidate_row)
        
        if candidate_row not in candidate_list:
            candidate_list.append(candidate_row)
            candidate_votes_dict [candidate_row] = 0
            print(candidate_list)
            print(candidate_votes_dict)

        candidate_votes_dict[candidate_row] = candidate_votes_dict[candidate_row] + 1
        print(candidate_votes_dict)

print (candidate_list)
print (candidate_votes_dict)

with open(file_to_output, "w") as txt_file:
    
# Print the final vote count (to bash)
    election_results = (
        f"\n\nElection Results\n"
        f"-------------------------\n"
        f"Total Votes: {total_votes_count}\n"
        f"-------------------------\n")
    print(election_results, end="")
    txt_file.write(election_results)
    
    for candidate in candidate_votes_dict: 
        candidate_vote = candidate_votes_dict.get(candidate)
        print(candidate_vote)
        vote_pct = (candidate_vote / total_votes_count) * 100

        if candidate_vote > candidate_winner_vote_count:
            candidate_winner_vote_count = candidate_vote
            candidate_winner = candidate
        
        voter_output = f"{candidate}: {vote_pct:.3f}% ({candidate_vote})\n"
        print(voter_output, end="")

       # Save each candidate's voter count and percentage to text file
        txt_file.write(voter_output)
# Out:
# ['Voter ID', 'County', 'Candidate']
# 1.0
# ['12864552', 'Marsh', 'Khan']
# Khan
# ['Khan']
# {'Khan': 0}
# {'Khan': 1}
# 2.0
# ['17444633', 'Marsh', 'Correy']
# Correy
# ['Khan', 'Correy']
# {'Khan': 1, 'Correy': 0}
# {'Khan': 1, 'Correy': 1}
# 3.0
# ['19330107', 'Marsh', 'Khan']
# Khan
# {'Khan': 2, 'Correy': 1}
# 4.0
# ['19865775', 'Queen', 'Khan']
# Khan
# {'Khan': 3, 'Correy': 1}
# 5.0
# ['11927875', 'Marsh', 'Khan']
# Khan
# {'Khan': 4, 'Correy': 1}
# 6.0
# ['19014606', 'Marsh', 'Li']
# Li
# ['Khan', 'Correy', 'Li']
# {'Khan': 4, 'Correy': 1, 'Li': 0}
# {'Khan': 4, 'Correy': 1, 'Li': 1}
# 7.0
# ['17775191', 'Queen', 'Correy']
# Correy
# {'Khan': 4, 'Correy': 2, 'Li': 1}
# 8.0
# ['14003692', 'Marsh', 'Khan']
# Khan
# {'Khan': 5, 'Correy': 2, 'Li': 1}
# 9.0
# ['14255761', 'Marsh', 'Khan']
# Khan
# {'Khan': 6, 'Correy': 2, 'Li': 1}
# 10.0
# ['13870173', 'Marsh', 'Correy']
# Correy
# {'Khan': 6, 'Correy': 3, 'Li': 1}
# 11.0
# ['16793141', 'Marsh', 'Khan']
# Khan
# {'Khan': 7, 'Correy': 3, 'Li': 1}
# 12.0
# ['10591158', 'Bamoo', 'Correy']
# Correy
# {'Khan': 7, 'Correy': 4, 'Li': 1}
# 13.0
# ['12344763', 'Trandee', 'Khan']
# Khan
# {'Khan': 8, 'Correy': 4, 'Li': 1}
# 14.0
# ['18611011', 'Marsh', 'Khan']
# Khan
# {'Khan': 9, 'Correy': 4, 'Li': 1}
# 15.0
# ['17845903', 'Marsh', 'Correy']
# Correy
# {'Khan': 9, 'Correy': 5, 'Li': 1}
# 16.0
# ['12621425', 'Trandee', 'Khan']
# Khan
# {'Khan': 10, 'Correy': 5, 'Li': 1}
# 17.0
# ['14365844', 'Marsh', 'Correy']
# Correy
# {'Khan': 10, 'Correy': 6, 'Li': 1}
# 18.0
# ['13444989', 'Marsh', 'Correy']
# Correy
# {'Khan': 10, 'Correy': 7, 'Li': 1}
# 19.0
# ['19204501', 'Trandee', 'Khan']
# Khan
# {'Khan': 11, 'Correy': 7, 'Li': 1}
# 20.0
# ['10098063', 'Queen', 'Correy']
# Correy
# {'Khan': 11, 'Correy': 8, 'Li': 1}
# 21.0
# ['19843246', 'Marsh', 'Correy']
# Correy
# {'Khan': 11, 'Correy': 9, 'Li': 1}
# 22.0
# ['11509120', 'Marsh', 'Correy']
# Correy
# {'Khan': 11, 'Correy': 10, 'Li': 1}
# 23.0
# ['13402499', 'Marsh', 'Correy']
# Correy
# {'Khan': 11, 'Correy': 11, 'Li': 1}
# 24.0
# ['18138694', 'Marsh', 'Khan']
# Khan
# {'Khan': 12, 'Correy': 11, 'Li': 1}
# 25.0
# ['15056703', 'Marsh', 'Khan']
# Khan
# {'Khan': 13, 'Correy': 11, 'Li': 1}
# 26.0
# ['12026178', 'Queen', 'Khan']
# Khan
# {'Khan': 14, 'Correy': 11, 'Li': 1}
# 27.0
# ['16667390', 'Marsh', 'Khan']
# Khan
# {'Khan': 15, 'Correy': 11, 'Li': 1}
# 28.0
# ['12847422', 'Queen', 'Khan']
# Khan
# {'Khan': 16, 'Correy': 11, 'Li': 1}
# 29.0
# ['10599242', 'Marsh', 'Khan']
# Khan
# {'Khan': 17, 'Correy': 11, 'Li': 1}
# 30.0
# ['18558857', 'Queen', 'Correy']
# Correy
# {'Khan': 17, 'Correy': 12, 'Li': 1}
# 31.0
# ['19533707', 'Queen', 'Correy']
# Correy
# {'Khan': 17, 'Correy': 13, 'Li': 1}
# 32.0
# ['13360545', 'Marsh', 'Khan']
# Khan
# {'Khan': 18, 'Correy': 13, 'Li': 1}
# 33.0
# ['13212178', 'Queen', 'Khan']
# Khan
# {'Khan': 19, 'Correy': 13, 'Li': 1}
# 34.0
# ['11154929', 'Marsh', 'Khan']
# Khan
# {'Khan': 20, 'Correy': 13, 'Li': 1}
# 35.0
# ['19602413', 'Marsh', 'Khan']
# Khan
# {'Khan': 21, 'Correy': 13, 'Li': 1}
# 36.0
# ['15405592', 'Marsh', 'Khan']
# Khan
# {'Khan': 22, 'Correy': 13, 'Li': 1}
# 37.0
# ['19561790', 'Marsh', 'Khan']
# Khan
# {'Khan': 23, 'Correy': 13, 'Li': 1}
# 38.0
# ['17094559', 'Marsh', 'Li']
# Li
# {'Khan': 23, 'Correy': 13, 'Li': 2}
# 39.0
# ['18233965', 'Marsh', 'Li']
# Li
# {'Khan': 23, 'Correy': 13, 'Li': 3}
# 40.0
# ['19984144', 'Marsh', 'Khan']
# Khan
# {'Khan': 24, 'Correy': 13, 'Li': 3}
# 41.0
# ['16973343', 'Trandee', 'Khan']
# Khan
# {'Khan': 25, 'Correy': 13, 'Li': 3}
# 42.0
# ['17295190', 'Marsh', 'Khan']
# Khan
# {'Khan': 26, 'Correy': 13, 'Li': 3}
# 43.0
# ['18554319', 'Marsh', 'Khan']
# Khan
# {'Khan': 27, 'Correy': 13, 'Li': 3}
# 44.0
# ['15611748', 'Raffah', 'Khan']
# Khan
# {'Khan': 28, 'Correy': 13, 'Li': 3}
# 45.0
# ['12354752', 'Marsh', 'Khan']
# Khan
# {'Khan': 29, 'Correy': 13, 'Li': 3}
# 46.0
# ['19600774', 'Marsh', 'Khan']
# Khan
# {'Khan': 30, 'Correy': 13, 'Li': 3}
# 47.0
# ['18121503', 'Bamoo', "O'Tooley"]
# O'Tooley
# ['Khan', 'Correy', 'Li', "O'Tooley"]
# {'Khan': 30, 'Correy': 13, 'Li': 3, "O'Tooley": 0}
# {'Khan': 30, 'Correy': 13, 'Li': 3, "O'Tooley": 1}
# 48.0
# ['16911714', 'Marsh', 'Khan']
# Khan
# {'Khan': 31, 'Correy': 13, 'Li': 3, "O'Tooley": 1}
# 49.0
# ['14187424', 'Marsh', 'Khan']
# Khan
# {'Khan': 32, 'Correy': 13, 'Li': 3, "O'Tooley": 1}
# 50.0
# ['12753806', 'Marsh', 'Khan']
# Khan
# {'Khan': 33, 'Correy': 13, 'Li': 3, "O'Tooley": 1}
# 51.0
# ['12558332', 'Marsh', 'Khan']
# Khan
# {'Khan': 34, 'Correy': 13, 'Li': 3, "O'Tooley": 1}
# 52.0
# ['12135098', 'Marsh', 'Khan']
# Khan
# {'Khan': 35, 'Correy': 13, 'Li': 3, "O'Tooley": 1}
# 53.0
# ['10985784', 'Queen', 'Khan']
# Khan
# {'Khan': 36, 'Correy': 13, 'Li': 3, "O'Tooley": 1}
# 54.0
# ['16471243', 'Marsh', 'Li']
# Li
# {'Khan': 36, 'Correy': 13, 'Li': 4, "O'Tooley": 1}
# 55.0
# ['14671650', 'Bamoo', 'Li']
# Li
# {'Khan': 36, 'Correy': 13, 'Li': 5, "O'Tooley": 1}
# 56.0
# ['18678460', 'Marsh', 'Li']
# Li
# {'Khan': 36, 'Correy': 13, 'Li': 6, "O'Tooley": 1}
# 57.0
# ['19697964', 'Bamoo', 'Khan']
# Khan
# {'Khan': 37, 'Correy': 13, 'Li': 6, "O'Tooley": 1}
# 58.0
# ['13317391', 'Marsh', 'Khan']
# Khan
# {'Khan': 38, 'Correy': 13, 'Li': 6, "O'Tooley": 1}
# 59.0
# ['10546494', 'Marsh', 'Correy']
# Correy
# {'Khan': 38, 'Correy': 14, 'Li': 6, "O'Tooley": 1}
# 60.0
# ['17187093', 'Marsh', 'Khan']
# Khan
# {'Khan': 39, 'Correy': 14, 'Li': 6, "O'Tooley": 1}
# 61.0
# ['16592767', 'Marsh', 'Khan']
# Khan
# {'Khan': 40, 'Correy': 14, 'Li': 6, "O'Tooley": 1}
# 62.0
# ['10495056', 'Queen', 'Khan']
# Khan
# {'Khan': 41, 'Correy': 14, 'Li': 6, "O'Tooley": 1}
# 63.0
# ['18469894', 'Marsh', 'Khan']
# Khan
# {'Khan': 42, 'Correy': 14, 'Li': 6, "O'Tooley": 1}
# 64.0
# ['16986900', 'Queen', 'Correy']
# Correy
# {'Khan': 42, 'Correy': 15, 'Li': 6, "O'Tooley": 1}
# 65.0
# ['10354536', 'Marsh', 'Khan']
# Khan
# {'Khan': 43, 'Correy': 15, 'Li': 6, "O'Tooley": 1}
# 66.0
# ['15503560', 'Queen', 'Khan']
# Khan
# {'Khan': 44, 'Correy': 15, 'Li': 6, "O'Tooley": 1}
# 67.0
# ['12455481', 'Marsh', 'Khan']
# Khan
# {'Khan': 45, 'Correy': 15, 'Li': 6, "O'Tooley": 1}
# 68.0
# ['19288647', 'Queen', "O'Tooley"]
# O'Tooley
# {'Khan': 45, 'Correy': 15, 'Li': 6, "O'Tooley": 2}
# 69.0
# ['14628255', 'Marsh', 'Li']
# Li
# {'Khan': 45, 'Correy': 15, 'Li': 7, "O'Tooley": 2}
# 70.0
# ['12204953', 'Marsh', 'Khan']
# Khan
# {'Khan': 46, 'Correy': 15, 'Li': 7, "O'Tooley": 2}
# 71.0
# ['11898633', 'Bamoo', 'Correy']
# Correy
# {'Khan': 46, 'Correy': 16, 'Li': 7, "O'Tooley": 2}
# 72.0
# ['15507376', 'Queen', 'Khan']
# Khan
# {'Khan': 47, 'Correy': 16, 'Li': 7, "O'Tooley": 2}
# 73.0
# ['15568341', 'Marsh', 'Khan']
# Khan
# {'Khan': 48, 'Correy': 16, 'Li': 7, "O'Tooley": 2}
# 74.0
# ['11893229', 'Queen', 'Khan']
# Khan
# {'Khan': 49, 'Correy': 16, 'Li': 7, "O'Tooley": 2}
# 75.0
# ['11959936', 'Marsh', 'Khan']
# Khan
# {'Khan': 50, 'Correy': 16, 'Li': 7, "O'Tooley": 2}
# 76.0
# ['13983895', 'Marsh', 'Khan']
# Khan
# {'Khan': 51, 'Correy': 16, 'Li': 7, "O'Tooley": 2}
# 77.0
# ['10681107', 'Marsh', 'Correy']
# Correy
# {'Khan': 51, 'Correy': 17, 'Li': 7, "O'Tooley": 2}
# 78.0
# ['13159206', 'Marsh', 'Khan']
# Khan
# {'Khan': 52, 'Correy': 17, 'Li': 7, "O'Tooley": 2}
# 79.0
# ['17526080', 'Marsh', 'Khan']
# Khan
# {'Khan': 53, 'Correy': 17, 'Li': 7, "O'Tooley": 2}
# 80.0
# ['18778133', 'Queen', 'Khan']
# Khan
# {'Khan': 54, 'Correy': 17, 'Li': 7, "O'Tooley": 2}
# 81.0
# ['18908438', 'Marsh', 'Li']
# Li
# {'Khan': 54, 'Correy': 17, 'Li': 8, "O'Tooley": 2}
# 82.0
# ['19043853', 'Marsh', 'Khan']
# Khan
# {'Khan': 55, 'Correy': 17, 'Li': 8, "O'Tooley": 2}
# 83.0
# ['16923106', 'Marsh', 'Khan']
# Khan
# {'Khan': 56, 'Correy': 17, 'Li': 8, "O'Tooley": 2}
# 84.0
# ['15687359', 'Marsh', 'Khan']
# Khan
# {'Khan': 57, 'Correy': 17, 'Li': 8, "O'Tooley": 2}
# 85.0
# ['12873603', 'Queen', 'Khan']
# Khan
# {'Khan': 58, 'Correy': 17, 'Li': 8, "O'Tooley": 2}
# 86.0
# ['14208674', 'Bamoo', 'Khan']
# Khan
# {'Khan': 59, 'Correy': 17, 'Li': 8, "O'Tooley": 2}
# 87.0
# ['15327117', 'Marsh', 'Khan']
# Khan
# {'Khan': 60, 'Correy': 17, 'Li': 8, "O'Tooley": 2}
# 88.0
# ['17286320', 'Marsh', 'Khan']
# Khan
# {'Khan': 61, 'Correy': 17, 'Li': 8, "O'Tooley": 2}
# 89.0
# ['12522584', 'Marsh', 'Khan']
# Khan
# {'Khan': 62, 'Correy': 17, 'Li': 8, "O'Tooley": 2}
# 90.0
# ['19231755', 'Queen', 'Khan']
# Khan
# {'Khan': 63, 'Correy': 17, 'Li': 8, "O'Tooley": 2}
# 91.0
# ['13073690', 'Marsh', 'Khan']
# Khan
# {'Khan': 64, 'Correy': 17, 'Li': 8, "O'Tooley": 2}
# 92.0
# ['13457436', 'Trandee', 'Khan']
# Khan
# {'Khan': 65, 'Correy': 17, 'Li': 8, "O'Tooley": 2}
# 93.0
# ['19973957', 'Queen', 'Khan']
# Khan
# {'Khan': 66, 'Correy': 17, 'Li': 8, "O'Tooley": 2}
# 94.0
# ['10315605', 'Trandee', 'Khan']
# Khan
# {'Khan': 67, 'Correy': 17, 'Li': 8, "O'Tooley": 2}
# 95.0
# ['12936845', 'Marsh', 'Correy']
# Correy
# {'Khan': 67, 'Correy': 18, 'Li': 8, "O'Tooley": 2}
# 96.0
# ['18052904', 'Bamoo', 'Khan']
# Khan
# {'Khan': 68, 'Correy': 18, 'Li': 8, "O'Tooley": 2}
# 97.0
# ['15563039', 'Marsh', 'Khan']
# Khan
# {'Khan': 69, 'Correy': 18, 'Li': 8, "O'Tooley": 2}
# 98.0
# ['10146708', 'Marsh', 'Khan']
# Khan
# {'Khan': 70, 'Correy': 18, 'Li': 8, "O'Tooley": 2}
# 99.0
# ['15152016', 'Marsh', 'Khan']
# Khan
# {'Khan': 71, 'Correy': 18, 'Li': 8, "O'Tooley": 2}
# 100.0
# ['15235971', 'Marsh', 'Khan']
# Khan
# {'Khan': 72, 'Correy': 18, 'Li': 8, "O'Tooley": 2}
# 101.0
# ['17631127', 'Marsh', 'Khan']
# Khan
# {'Khan': 73, 'Correy': 18, 'Li': 8, "O'Tooley": 2}
# 102.0
# ['11012216', 'Queen', 'Li']
# Li
# {'Khan': 73, 'Correy': 18, 'Li': 9, "O'Tooley": 2}
# 103.0
# ['10687887', 'Marsh', 'Khan']
# Khan
# {'Khan': 74, 'Correy': 18, 'Li': 9, "O'Tooley": 2}
# 104.0
# ['11555429', 'Marsh', 'Khan']
# Khan
# {'Khan': 75, 'Correy': 18, 'Li': 9, "O'Tooley": 2}
# 105.0
# ['17333717', 'Marsh', 'Li']
# Li
# {'Khan': 75, 'Correy': 18, 'Li': 10, "O'Tooley": 2}
# 106.0
# ['18087110', 'Marsh', 'Correy']
# Correy
# {'Khan': 75, 'Correy': 19, 'Li': 10, "O'Tooley": 2}
# 107.0
# ['12373068', 'Marsh', 'Khan']
# Khan
# {'Khan': 76, 'Correy': 19, 'Li': 10, "O'Tooley": 2}
# 108.0
# ['11332203', 'Queen', 'Correy']
# Correy
# {'Khan': 76, 'Correy': 20, 'Li': 10, "O'Tooley": 2}
# 109.0
# ['18959391', 'Queen', 'Khan']
# Khan
# {'Khan': 77, 'Correy': 20, 'Li': 10, "O'Tooley": 2}
# 110.0
# ['10928071', 'Marsh', 'Li']
# Li
# {'Khan': 77, 'Correy': 20, 'Li': 11, "O'Tooley": 2}
# 111.0
# ['14594455', 'Marsh', 'Khan']
# Khan
# {'Khan': 78, 'Correy': 20, 'Li': 11, "O'Tooley": 2}
# 112.0
# ['19070201', 'Marsh', 'Khan']
# Khan
# {'Khan': 79, 'Correy': 20, 'Li': 11, "O'Tooley": 2}
# 113.0
# ['14384849', 'Marsh', 'Khan']
# Khan
# {'Khan': 80, 'Correy': 20, 'Li': 11, "O'Tooley": 2}
# 114.0
# ['19613019', 'Marsh', 'Khan']
# Khan
# {'Khan': 81, 'Correy': 20, 'Li': 11, "O'Tooley": 2}
# 115.0
# ['19917014', 'Marsh', 'Khan']
# Khan
# {'Khan': 82, 'Correy': 20, 'Li': 11, "O'Tooley": 2}
# 116.0
# ['15174536', 'Queen', 'Correy']
# Correy
# {'Khan': 82, 'Correy': 21, 'Li': 11, "O'Tooley": 2}
# 117.0
# ['10685996', 'Marsh', 'Correy']
# Correy
# {'Khan': 82, 'Correy': 22, 'Li': 11, "O'Tooley": 2}
# 118.0
# ['10194903', 'Marsh', 'Khan']
# Khan
# {'Khan': 83, 'Correy': 22, 'Li': 11, "O'Tooley": 2}
# 119.0
# ['15430548', 'Queen', 'Khan']
# Khan
# {'Khan': 84, 'Correy': 22, 'Li': 11, "O'Tooley": 2}
# 120.0
# ['16498078', 'Marsh', 'Khan']
# Khan
# {'Khan': 85, 'Correy': 22, 'Li': 11, "O'Tooley": 2}
# 121.0
# ['18245450', 'Marsh', 'Khan']
# Khan
# {'Khan': 86, 'Correy': 22, 'Li': 11, "O'Tooley": 2}
# 122.0
# ['16256895', 'Marsh', 'Correy']
# Correy
# {'Khan': 86, 'Correy': 23, 'Li': 11, "O'Tooley": 2}
# 123.0
# ['17629989', 'Marsh', 'Khan']
# Khan
# {'Khan': 87, 'Correy': 23, 'Li': 11, "O'Tooley": 2}
# 124.0
# ['12646555', 'Marsh', 'Correy']
# Correy
# {'Khan': 87, 'Correy': 24, 'Li': 11, "O'Tooley": 2}
# 125.0
# ['18482309', 'Trandee', 'Khan']
# Khan
# {'Khan': 88, 'Correy': 24, 'Li': 11, "O'Tooley": 2}
# 126.0
# ['13167245', 'Queen', 'Khan']
# Khan
# {'Khan': 89, 'Correy': 24, 'Li': 11, "O'Tooley": 2}
# 127.0
# ['16206129', 'Marsh', 'Khan']
# Khan
# {'Khan': 90, 'Correy': 24, 'Li': 11, "O'Tooley": 2}
# 128.0
# ['16117205', 'Marsh', 'Khan']
# Khan
# {'Khan': 91, 'Correy': 24, 'Li': 11, "O'Tooley": 2}
# 129.0
# ['10988917', 'Queen', 'Khan']
# Khan
# {'Khan': 92, 'Correy': 24, 'Li': 11, "O'Tooley": 2}
# 130.0
# ['14704548', 'Queen', 'Khan']
# Khan
# {'Khan': 93, 'Correy': 24, 'Li': 11, "O'Tooley": 2}
# 131.0
# ['17601677', 'Bamoo', 'Khan']
# Khan
# {'Khan': 94, 'Correy': 24, 'Li': 11, "O'Tooley": 2}
# 132.0
# ['15486579', 'Marsh', 'Khan']
# Khan
# {'Khan': 95, 'Correy': 24, 'Li': 11, "O'Tooley": 2}
# 133.0
# ['18495978', 'Marsh', 'Correy']
# Correy
# {'Khan': 95, 'Correy': 25, 'Li': 11, "O'Tooley": 2}
# 134.0
# ['17834864', 'Marsh', 'Khan']
# Khan
# {'Khan': 96, 'Correy': 25, 'Li': 11, "O'Tooley": 2}
# 135.0
# ['15363702', 'Marsh', 'Khan']
# Khan
# {'Khan': 97, 'Correy': 25, 'Li': 11, "O'Tooley": 2}
# 136.0
# ['17558406', 'Marsh', 'Correy']
# Correy
# {'Khan': 97, 'Correy': 26, 'Li': 11, "O'Tooley": 2}
# 137.0
# ['17050987', 'Marsh', 'Khan']
# Khan
# {'Khan': 98, 'Correy': 26, 'Li': 11, "O'Tooley": 2}
# 138.0
# ['10156191', 'Marsh', 'Khan']
# Khan
# {'Khan': 99, 'Correy': 26, 'Li': 11, "O'Tooley": 2}
# 139.0
# ['11990779', 'Marsh', 'Khan']
# Khan
# {'Khan': 100, 'Correy': 26, 'Li': 11, "O'Tooley": 2}
# 140.0
# ['14524191', 'Marsh', 'Khan']
# Khan
# {'Khan': 101, 'Correy': 26, 'Li': 11, "O'Tooley": 2}
# 141.0
# ['16639341', 'Marsh', 'Correy']
# Correy
# {'Khan': 101, 'Correy': 27, 'Li': 11, "O'Tooley": 2}
# 142.0
# ['18298755', 'Queen', 'Khan']
# Khan
# {'Khan': 102, 'Correy': 27, 'Li': 11, "O'Tooley": 2}
# 143.0
# ['19758369', 'Queen', 'Correy']
# Correy
# {'Khan': 102, 'Correy': 28, 'Li': 11, "O'Tooley": 2}
# 144.0
# ['19392797', 'Queen', 'Khan']
# Khan
# {'Khan': 103, 'Correy': 28, 'Li': 11, "O'Tooley": 2}
# 145.0
# ['13276997', 'Marsh', 'Khan']
# Khan
# {'Khan': 104, 'Correy': 28, 'Li': 11, "O'Tooley": 2}
# 146.0
# ['16435563', 'Marsh', 'Correy']
# Correy
# {'Khan': 104, 'Correy': 29, 'Li': 11, "O'Tooley": 2}
# 147.0
# ['17400011', 'Marsh', 'Khan']
# Khan
# {'Khan': 105, 'Correy': 29, 'Li': 11, "O'Tooley": 2}
# 148.0
# ['19427653', 'Marsh', 'Khan']
# Khan
# {'Khan': 106, 'Correy': 29, 'Li': 11, "O'Tooley": 2}
# 149.0
# ['18943426', 'Marsh', 'Khan']
# Khan
# {'Khan': 107, 'Correy': 29, 'Li': 11, "O'Tooley": 2}
# 150.0
# ['12000466', 'Bamoo', 'Li']
# Li
# {'Khan': 107, 'Correy': 29, 'Li': 12, "O'Tooley": 2}
# 151.0
# ['11295263', 'Marsh', 'Correy']
# Correy
# {'Khan': 107, 'Correy': 30, 'Li': 12, "O'Tooley": 2}
# 152.0
# ['16746898', 'Marsh', 'Khan']
# Khan
# {'Khan': 108, 'Correy': 30, 'Li': 12, "O'Tooley": 2}
# 153.0
# ['15966636', 'Marsh', 'Khan']
# Khan
# {'Khan': 109, 'Correy': 30, 'Li': 12, "O'Tooley": 2}
# 154.0
# ['15118362', 'Marsh', 'Khan']
# Khan
# {'Khan': 110, 'Correy': 30, 'Li': 12, "O'Tooley": 2}
# 155.0
# ['15872797', 'Bamoo', 'Li']
# Li
# {'Khan': 110, 'Correy': 30, 'Li': 13, "O'Tooley": 2}
# 156.0
# ['14518825', 'Marsh', 'Khan']
# Khan
# {'Khan': 111, 'Correy': 30, 'Li': 13, "O'Tooley": 2}
# 157.0
# ['19839716', 'Marsh', 'Khan']
# Khan
# {'Khan': 112, 'Correy': 30, 'Li': 13, "O'Tooley": 2}
# 158.0
# ['16672147', 'Bamoo', "O'Tooley"]
# O'Tooley
# {'Khan': 112, 'Correy': 30, 'Li': 13, "O'Tooley": 3}
# 159.0
# ['16124460', 'Marsh', 'Khan']
# Khan
# {'Khan': 113, 'Correy': 30, 'Li': 13, "O'Tooley": 3}
# 160.0
# ['15502644', 'Marsh', 'Li']
# Li
# {'Khan': 113, 'Correy': 30, 'Li': 14, "O'Tooley": 3}
# 161.0
# ['10858409', 'Marsh', 'Khan']
# Khan
# {'Khan': 114, 'Correy': 30, 'Li': 14, "O'Tooley": 3}
# 162.0
# ['17248475', 'Marsh', 'Khan']
# Khan
# {'Khan': 115, 'Correy': 30, 'Li': 14, "O'Tooley": 3}
# 163.0
# ['18882298', 'Queen', 'Khan']
# Khan
# {'Khan': 116, 'Correy': 30, 'Li': 14, "O'Tooley": 3}
# 164.0
# ['18320834', 'Marsh', 'Li']
# Li
# {'Khan': 116, 'Correy': 30, 'Li': 15, "O'Tooley": 3}
# 165.0
# ['15838622', 'Marsh', 'Correy']
# Correy
# {'Khan': 116, 'Correy': 31, 'Li': 15, "O'Tooley": 3}
# 166.0
# ['17706596', 'Marsh', 'Khan']
# Khan
# {'Khan': 117, 'Correy': 31, 'Li': 15, "O'Tooley": 3}
# 167.0
# ['11549801', 'Marsh', 'Li']
# Li
# {'Khan': 117, 'Correy': 31, 'Li': 16, "O'Tooley": 3}
# 168.0
# ['10759070', 'Queen', 'Khan']
# Khan
# {'Khan': 118, 'Correy': 31, 'Li': 16, "O'Tooley": 3}
# 169.0
# ['10482609', 'Raffah', 'Khan']
# Khan
# {'Khan': 119, 'Correy': 31, 'Li': 16, "O'Tooley": 3}
# 170.0
# ['13276638', 'Bamoo', 'Correy']
# Correy
# {'Khan': 119, 'Correy': 32, 'Li': 16, "O'Tooley": 3}
# 171.0
# ['13728070', 'Marsh', 'Khan']
# Khan
# {'Khan': 120, 'Correy': 32, 'Li': 16, "O'Tooley": 3}
# 172.0
# ['19229195', 'Queen', 'Khan']
# Khan
# {'Khan': 121, 'Correy': 32, 'Li': 16, "O'Tooley": 3}
# 173.0
# ['11063812', 'Queen', 'Li']
# Li
# {'Khan': 121, 'Correy': 32, 'Li': 17, "O'Tooley": 3}
# 174.0
# ['13518182', 'Marsh', 'Correy']
# Correy
# {'Khan': 121, 'Correy': 33, 'Li': 17, "O'Tooley": 3}
# 175.0
# ['14969961', 'Marsh', 'Correy']
# Correy
# {'Khan': 121, 'Correy': 34, 'Li': 17, "O'Tooley": 3}
# 176.0
# ['15365084', 'Queen', 'Correy']
# Correy
# {'Khan': 121, 'Correy': 35, 'Li': 17, "O'Tooley": 3}
# 177.0
# ['15898970', 'Marsh', 'Correy']
# Correy
# {'Khan': 121, 'Correy': 36, 'Li': 17, "O'Tooley": 3}
# 178.0
# ['16962401', 'Queen', 'Khan']
# Khan
# {'Khan': 122, 'Correy': 36, 'Li': 17, "O'Tooley": 3}
# 179.0
# ['19900365', 'Marsh', 'Khan']
# Khan
# {'Khan': 123, 'Correy': 36, 'Li': 17, "O'Tooley": 3}
# 180.0
# ['11370360', 'Raffah', 'Li']
# Li
# {'Khan': 123, 'Correy': 36, 'Li': 18, "O'Tooley": 3}
# 181.0
# ['19003962', 'Bamoo', 'Khan']
# Khan
# {'Khan': 124, 'Correy': 36, 'Li': 18, "O'Tooley": 3}
# 182.0
# ['10699676', 'Marsh', 'Li']
# Li
# {'Khan': 124, 'Correy': 36, 'Li': 19, "O'Tooley": 3}
# 183.0
# ['17797089', 'Queen', 'Khan']
# Khan
# {'Khan': 125, 'Correy': 36, 'Li': 19, "O'Tooley": 3}
# 184.0
# ['12063159', 'Marsh', 'Khan']
# Khan
# {'Khan': 126, 'Correy': 36, 'Li': 19, "O'Tooley": 3}
# 185.0
# ['13174545', 'Queen', 'Khan']
# Khan
# {'Khan': 127, 'Correy': 36, 'Li': 19, "O'Tooley": 3}
# 186.0
# ['19015260', 'Queen', 'Khan']
# Khan
# {'Khan': 128, 'Correy': 36, 'Li': 19, "O'Tooley": 3}
# 187.0
# ['11557251', 'Trandee', 'Khan']
# Khan
# {'Khan': 129, 'Correy': 36, 'Li': 19, "O'Tooley": 3}
# 188.0
# ['16432362', 'Queen', 'Khan']
# Khan
# {'Khan': 130, 'Correy': 36, 'Li': 19, "O'Tooley": 3}
# 189.0
# ['12323740', 'Queen', 'Khan']
# Khan
# {'Khan': 131, 'Correy': 36, 'Li': 19, "O'Tooley": 3}
# 190.0
# ['12415636', 'Marsh', 'Li']
# Li
# {'Khan': 131, 'Correy': 36, 'Li': 20, "O'Tooley": 3}
# 191.0
# ['14877742', 'Queen', 'Khan']
# Khan
# {'Khan': 132, 'Correy': 36, 'Li': 20, "O'Tooley": 3}
# 192.0
# ['10854862', 'Marsh', 'Correy']
# Correy
# {'Khan': 132, 'Correy': 37, 'Li': 20, "O'Tooley": 3}
# 193.0
# ['15380105', 'Queen', 'Khan']
# Khan
# {'Khan': 133, 'Correy': 37, 'Li': 20, "O'Tooley": 3}
# 194.0
# ['18196072', 'Marsh', 'Khan']
# Khan
# {'Khan': 134, 'Correy': 37, 'Li': 20, "O'Tooley": 3}
# 195.0
# ['12245331', 'Marsh', 'Khan']
# Khan
# {'Khan': 135, 'Correy': 37, 'Li': 20, "O'Tooley": 3}
# 196.0
# ['16717985', 'Bamoo', 'Correy']
# Correy
# {'Khan': 135, 'Correy': 38, 'Li': 20, "O'Tooley": 3}
# 197.0
# ['15050784', 'Queen', 'Khan']
# Khan
# {'Khan': 136, 'Correy': 38, 'Li': 20, "O'Tooley": 3}
# 198.0
# ['13370357', 'Queen', 'Khan']
# Khan
# {'Khan': 137, 'Correy': 38, 'Li': 20, "O'Tooley": 3}
# 199.0
# ['16741235', 'Queen', 'Khan']
# Khan
# {'Khan': 138, 'Correy': 38, 'Li': 20, "O'Tooley": 3}
# 200.0
# ['10973853', 'Marsh', 'Li']
# Li
# {'Khan': 138, 'Correy': 38, 'Li': 21, "O'Tooley": 3}
# 201.0
# ['12290835', 'Marsh', 'Khan']
# Khan
# {'Khan': 139, 'Correy': 38, 'Li': 21, "O'Tooley": 3}
# 202.0
# ['13220018', 'Marsh', 'Li']
# Li
# {'Khan': 139, 'Correy': 38, 'Li': 22, "O'Tooley": 3}
# 203.0
# ['15364710', 'Marsh', 'Li']
# Li
# {'Khan': 139, 'Correy': 38, 'Li': 23, "O'Tooley": 3}
# 204.0
# ['17190051', 'Raffah', 'Correy']
# Correy
# {'Khan': 139, 'Correy': 39, 'Li': 23, "O'Tooley": 3}
# 205.0
# ['13153220', 'Marsh', 'Correy']
# Correy
# {'Khan': 139, 'Correy': 40, 'Li': 23, "O'Tooley": 3}
# 206.0
# ['15781572', 'Bamoo', 'Li']
# Li
# {'Khan': 139, 'Correy': 40, 'Li': 24, "O'Tooley": 3}
# 207.0
# ['16872631', 'Marsh', 'Li']
# Li
# {'Khan': 139, 'Correy': 40, 'Li': 25, "O'Tooley": 3}
# 208.0
# ['11697401', 'Marsh', 'Khan']
# Khan
# {'Khan': 140, 'Correy': 40, 'Li': 25, "O'Tooley": 3}
# 209.0
# ['11319843', 'Marsh', 'Correy']
# Correy
# {'Khan': 140, 'Correy': 41, 'Li': 25, "O'Tooley": 3}
# 210.0
# ['13640798', 'Marsh', 'Khan']
# Khan
# {'Khan': 141, 'Correy': 41, 'Li': 25, "O'Tooley": 3}
# 211.0
# ['18246891', 'Raffah', 'Khan']
# Khan
# {'Khan': 142, 'Correy': 41, 'Li': 25, "O'Tooley": 3}
# 212.0
# ['16601877', 'Queen', 'Khan']
# Khan
# {'Khan': 143, 'Correy': 41, 'Li': 25, "O'Tooley": 3}
# 213.0
# ['12263216', 'Raffah', 'Khan']
# Khan
# {'Khan': 144, 'Correy': 41, 'Li': 25, "O'Tooley": 3}
# 214.0
# ['12743147', 'Marsh', 'Khan']
# Khan
# {'Khan': 145, 'Correy': 41, 'Li': 25, "O'Tooley": 3}
# 215.0
# ['19658217', 'Bamoo', 'Khan']
# Khan
# {'Khan': 146, 'Correy': 41, 'Li': 25, "O'Tooley": 3}
# 216.0
# ['11031357', 'Marsh', 'Correy']
# Correy
# {'Khan': 146, 'Correy': 42, 'Li': 25, "O'Tooley": 3}
# 217.0
# ['18831515', 'Marsh', 'Khan']
# Khan
# {'Khan': 147, 'Correy': 42, 'Li': 25, "O'Tooley": 3}
# 218.0
# ['11992924', 'Marsh', 'Correy']
# Correy
# {'Khan': 147, 'Correy': 43, 'Li': 25, "O'Tooley": 3}
# 219.0
# ['16268716', 'Marsh', 'Khan']
# Khan
# {'Khan': 148, 'Correy': 43, 'Li': 25, "O'Tooley": 3}
# 220.0
# ['10890839', 'Marsh', 'Correy']
# Correy
# {'Khan': 148, 'Correy': 44, 'Li': 25, "O'Tooley": 3}
# 221.0
# ['16132539', 'Queen', 'Li']
# Li
# {'Khan': 148, 'Correy': 44, 'Li': 26, "O'Tooley": 3}
# 222.0
# ['16292736', 'Marsh', 'Correy']
# Correy
# {'Khan': 148, 'Correy': 45, 'Li': 26, "O'Tooley": 3}
# 223.0
# ['18943340', 'Bamoo', 'Khan']
# Khan
# {'Khan': 149, 'Correy': 45, 'Li': 26, "O'Tooley": 3}
# 224.0
# ['16546436', 'Marsh', 'Li']
# Li
# {'Khan': 149, 'Correy': 45, 'Li': 27, "O'Tooley": 3}
# 225.0
# ['19679245', 'Marsh', 'Khan']
# Khan
# {'Khan': 150, 'Correy': 45, 'Li': 27, "O'Tooley": 3}
# 226.0
# ['17011253', 'Queen', 'Khan']
# Khan
# {'Khan': 151, 'Correy': 45, 'Li': 27, "O'Tooley": 3}
# 227.0
# ['13038414', 'Bamoo', 'Correy']
# Correy
# {'Khan': 151, 'Correy': 46, 'Li': 27, "O'Tooley": 3}
# 228.0
# ['11212334', 'Marsh', 'Khan']
# Khan
# {'Khan': 152, 'Correy': 46, 'Li': 27, "O'Tooley": 3}
# 229.0
# ['16071649', 'Marsh', 'Khan']
# Khan
# {'Khan': 153, 'Correy': 46, 'Li': 27, "O'Tooley": 3}
# 230.0
# ['14118076', 'Marsh', 'Li']
# Li
# {'Khan': 153, 'Correy': 46, 'Li': 28, "O'Tooley": 3}
# 231.0
# ['16859069', 'Marsh', 'Khan']
# Khan
# {'Khan': 154, 'Correy': 46, 'Li': 28, "O'Tooley": 3}
# 232.0
# ['17641181', 'Marsh', 'Li']
# Li
# {'Khan': 154, 'Correy': 46, 'Li': 29, "O'Tooley": 3}
# 233.0
# ['19464179', 'Trandee', 'Khan']
# Khan
# {'Khan': 155, 'Correy': 46, 'Li': 29, "O'Tooley": 3}
# 234.0
# ['18972334', 'Marsh', 'Correy']
# Correy
# {'Khan': 155, 'Correy': 47, 'Li': 29, "O'Tooley": 3}
# 235.0
# ['19907074', 'Queen', 'Khan']
# Khan
# {'Khan': 156, 'Correy': 47, 'Li': 29, "O'Tooley": 3}
# 236.0
# ['18013230', 'Marsh', 'Khan']
# Khan
# {'Khan': 157, 'Correy': 47, 'Li': 29, "O'Tooley": 3}
# 237.0
# ['11854082', 'Raffah', 'Khan']
# Khan
# {'Khan': 158, 'Correy': 47, 'Li': 29, "O'Tooley": 3}
# 238.0
# ['18908035', 'Marsh', 'Khan']
# Khan
# {'Khan': 159, 'Correy': 47, 'Li': 29, "O'Tooley": 3}
# 239.0
# ['18404019', 'Queen', 'Correy']
# Correy
# {'Khan': 159, 'Correy': 48, 'Li': 29, "O'Tooley": 3}
# 240.0
# ['19759637', 'Marsh', 'Correy']
# Correy
# {'Khan': 159, 'Correy': 49, 'Li': 29, "O'Tooley": 3}
# 241.0
# ['17752609', 'Queen', 'Khan']
# Khan
# {'Khan': 160, 'Correy': 49, 'Li': 29, "O'Tooley": 3}
# 242.0
# ['18433054', 'Queen', 'Khan']
# Khan
# {'Khan': 161, 'Correy': 49, 'Li': 29, "O'Tooley": 3}
# 243.0
# ['15811960', 'Marsh', 'Khan']
# Khan
# {'Khan': 162, 'Correy': 49, 'Li': 29, "O'Tooley": 3}
# 244.0
# ['18134790', 'Marsh', 'Li']
# Li
# {'Khan': 162, 'Correy': 49, 'Li': 30, "O'Tooley": 3}
# 245.0
# ['19667395', 'Marsh', 'Khan']
# Khan
# {'Khan': 163, 'Correy': 49, 'Li': 30, "O'Tooley": 3}
# 246.0
# ['17120606', 'Trandee', 'Khan']
# Khan
# {'Khan': 164, 'Correy': 49, 'Li': 30, "O'Tooley": 3}
# 247.0
# ['15925869', 'Marsh', 'Khan']
# Khan
# {'Khan': 165, 'Correy': 49, 'Li': 30, "O'Tooley": 3}
# 248.0
# ['15716463', 'Queen', 'Khan']
# Khan
# {'Khan': 166, 'Correy': 49, 'Li': 30, "O'Tooley": 3}
# 249.0
# ['18171107', 'Marsh', 'Correy']
# Correy
# {'Khan': 166, 'Correy': 50, 'Li': 30, "O'Tooley": 3}
# 250.0
# ['12642853', 'Queen', 'Khan']
# Khan
# {'Khan': 167, 'Correy': 50, 'Li': 30, "O'Tooley": 3}
# 251.0
# ['11624049', 'Trandee', 'Khan']
# Khan
# {'Khan': 168, 'Correy': 50, 'Li': 30, "O'Tooley": 3}
# 252.0
# ['19996587', 'Marsh', 'Khan']
# Khan
# {'Khan': 169, 'Correy': 50, 'Li': 30, "O'Tooley": 3}
# 253.0
# ['19204079', 'Queen', 'Correy']
# Correy
# {'Khan': 169, 'Correy': 51, 'Li': 30, "O'Tooley": 3}
# 254.0
# ['15625064', 'Marsh', 'Khan']
# Khan
# {'Khan': 170, 'Correy': 51, 'Li': 30, "O'Tooley": 3}
# 255.0
# ['17553703', 'Marsh', 'Correy']
# Correy
# {'Khan': 170, 'Correy': 52, 'Li': 30, "O'Tooley": 3}
# 256.0
# ['18078316', 'Marsh', 'Correy']
# Correy
# {'Khan': 170, 'Correy': 53, 'Li': 30, "O'Tooley": 3}
# 257.0
# ['11399651', 'Marsh', "O'Tooley"]
# O'Tooley
# {'Khan': 170, 'Correy': 53, 'Li': 30, "O'Tooley": 4}
# 258.0
# ['17858114', 'Marsh', 'Khan']
# Khan
# {'Khan': 171, 'Correy': 53, 'Li': 30, "O'Tooley": 4}
# 259.0
# ['14612586', 'Marsh', 'Li']
# Li
# {'Khan': 171, 'Correy': 53, 'Li': 31, "O'Tooley": 4}
# 260.0
# ['16676571', 'Marsh', 'Li']
# Li
# {'Khan': 171, 'Correy': 53, 'Li': 32, "O'Tooley": 4}
# 261.0
# ['13915279', 'Marsh', 'Khan']
# Khan
# {'Khan': 172, 'Correy': 53, 'Li': 32, "O'Tooley": 4}
# 262.0
# ['16066306', 'Marsh', 'Li']
# Li
# {'Khan': 172, 'Correy': 53, 'Li': 33, "O'Tooley": 4}
# 263.0
# ['12235364', 'Raffah', 'Khan']
# Khan
# {'Khan': 173, 'Correy': 53, 'Li': 33, "O'Tooley": 4}
# 264.0
# ['10507756', 'Bamoo', 'Khan']
# Khan
# {'Khan': 174, 'Correy': 53, 'Li': 33, "O'Tooley": 4}
# 265.0
# ['10247768', 'Marsh', 'Correy']
# Correy
# {'Khan': 174, 'Correy': 54, 'Li': 33, "O'Tooley": 4}
# 266.0
# ['19091957', 'Marsh', 'Khan']
# Khan
# {'Khan': 175, 'Correy': 54, 'Li': 33, "O'Tooley": 4}
# 267.0
# ['11125496', 'Marsh', 'Khan']
# Khan
# {'Khan': 176, 'Correy': 54, 'Li': 33, "O'Tooley": 4}
# 268.0
# ['19833873', 'Queen', 'Correy']
# Correy
# {'Khan': 176, 'Correy': 55, 'Li': 33, "O'Tooley": 4}
# 269.0
# ['12570146', 'Queen', 'Khan']
# Khan
# {'Khan': 177, 'Correy': 55, 'Li': 33, "O'Tooley": 4}
# 270.0
# ['13433636', 'Marsh', 'Khan']
# Khan
# {'Khan': 178, 'Correy': 55, 'Li': 33, "O'Tooley": 4}
# 271.0
# ['12692210', 'Marsh', 'Khan']
# Khan
# {'Khan': 179, 'Correy': 55, 'Li': 33, "O'Tooley": 4}
# 272.0
# ['14821740', 'Marsh', 'Khan']
# Khan
# {'Khan': 180, 'Correy': 55, 'Li': 33, "O'Tooley": 4}
# 273.0
# ['17942773', 'Marsh', 'Khan']
# Khan
# {'Khan': 181, 'Correy': 55, 'Li': 33, "O'Tooley": 4}
# 274.0
# ['16575311', 'Marsh', 'Correy']
# Correy
# {'Khan': 181, 'Correy': 56, 'Li': 33, "O'Tooley": 4}
# 275.0
# ['12686083', 'Bamoo', 'Khan']
# Khan
# {'Khan': 182, 'Correy': 56, 'Li': 33, "O'Tooley": 4}
# 276.0
# ['19028122', 'Marsh', 'Khan']
# Khan
# {'Khan': 183, 'Correy': 56, 'Li': 33, "O'Tooley": 4}
# 277.0
# ['14024998', 'Bamoo', 'Khan']
# Khan
# {'Khan': 184, 'Correy': 56, 'Li': 33, "O'Tooley": 4}
# 278.0
# ['12108177', 'Marsh', 'Correy']
# Correy
# {'Khan': 184, 'Correy': 57, 'Li': 33, "O'Tooley": 4}
# 279.0
# ['16155430', 'Marsh', 'Khan']
# Khan
# {'Khan': 185, 'Correy': 57, 'Li': 33, "O'Tooley": 4}
# 280.0
# ['14142750', 'Marsh', 'Khan']
# Khan
# {'Khan': 186, 'Correy': 57, 'Li': 33, "O'Tooley": 4}
# 281.0
# ['17823589', 'Marsh', 'Li']
# Li
# {'Khan': 186, 'Correy': 57, 'Li': 34, "O'Tooley": 4}
# 282.0
# ['10672413', 'Bamoo', 'Khan']
# Khan
# {'Khan': 187, 'Correy': 57, 'Li': 34, "O'Tooley": 4}
# 283.0
# ['18132127', 'Marsh', 'Correy']
# Correy
# {'Khan': 187, 'Correy': 58, 'Li': 34, "O'Tooley": 4}
# 284.0
# ['12425096', 'Marsh', "O'Tooley"]
# O'Tooley
# {'Khan': 187, 'Correy': 58, 'Li': 34, "O'Tooley": 5}
# 285.0
# ['11862887', 'Marsh', 'Li']
# Li
# {'Khan': 187, 'Correy': 58, 'Li': 35, "O'Tooley": 5}
# 286.0
# ['19785716', 'Queen', 'Khan']
# Khan
# {'Khan': 188, 'Correy': 58, 'Li': 35, "O'Tooley": 5}
# 287.0
# ['12391866', 'Bamoo', 'Li']
# Li
# {'Khan': 188, 'Correy': 58, 'Li': 36, "O'Tooley": 5}
# 288.0
# ['11259663', 'Bamoo', 'Khan']
# Khan
# {'Khan': 189, 'Correy': 58, 'Li': 36, "O'Tooley": 5}
# 289.0
# ['11306175', 'Marsh', 'Khan']
# Khan
# {'Khan': 190, 'Correy': 58, 'Li': 36, "O'Tooley": 5}
# 290.0
# ['16281776', 'Bamoo', 'Li']
# Li
# {'Khan': 190, 'Correy': 58, 'Li': 37, "O'Tooley": 5}
# 291.0
# ['12539730', 'Queen', 'Khan']
# Khan
# {'Khan': 191, 'Correy': 58, 'Li': 37, "O'Tooley": 5}
# 292.0
# ['15985290', 'Bamoo', 'Khan']
# Khan
# {'Khan': 192, 'Correy': 58, 'Li': 37, "O'Tooley": 5}
# 293.0
# ['10692848', 'Bamoo', 'Khan']
# Khan
# {'Khan': 193, 'Correy': 58, 'Li': 37, "O'Tooley": 5}
# 294.0
# ['18206301', 'Queen', 'Correy']
# Correy
# {'Khan': 193, 'Correy': 59, 'Li': 37, "O'Tooley": 5}
# 295.0
# ['12439581', 'Marsh', 'Correy']
# Correy
# {'Khan': 193, 'Correy': 60, 'Li': 37, "O'Tooley": 5}
# 296.0
# ['15823795', 'Marsh', 'Khan']
# Khan
# {'Khan': 194, 'Correy': 60, 'Li': 37, "O'Tooley": 5}
# 297.0
# ['18507561', 'Marsh', 'Li']
# Li
# {'Khan': 194, 'Correy': 60, 'Li': 38, "O'Tooley": 5}
# 298.0
# ['15182933', 'Marsh', 'Khan']
# Khan
# {'Khan': 195, 'Correy': 60, 'Li': 38, "O'Tooley": 5}
# 299.0
# ['13575214', 'Marsh', 'Khan']
# Khan
# {'Khan': 196, 'Correy': 60, 'Li': 38, "O'Tooley": 5}
# 300.0
# ['16435645', 'Marsh', 'Khan']
# Khan
# {'Khan': 197, 'Correy': 60, 'Li': 38, "O'Tooley": 5}
# 301.0
# ['19350378', 'Marsh', 'Khan']
# Khan
# {'Khan': 198, 'Correy': 60, 'Li': 38, "O'Tooley": 5}
# 302.0
# ['11995622', 'Marsh', 'Khan']
# Khan
# {'Khan': 199, 'Correy': 60, 'Li': 38, "O'Tooley": 5}
# 303.0
# ['19388234', 'Queen', 'Khan']
# Khan
# {'Khan': 200, 'Correy': 60, 'Li': 38, "O'Tooley": 5}
# 304.0
# ['13877967', 'Marsh', 'Khan']
# Khan
# {'Khan': 201, 'Correy': 60, 'Li': 38, "O'Tooley": 5}
# 305.0
# ['19909160', 'Marsh', 'Correy']
# Correy
# {'Khan': 201, 'Correy': 61, 'Li': 38, "O'Tooley": 5}
# 306.0
# ['13659503', 'Marsh', 'Khan']
# Khan
# {'Khan': 202, 'Correy': 61, 'Li': 38, "O'Tooley": 5}
# 307.0
# ['19134023', 'Marsh', 'Correy']
# Correy
# {'Khan': 202, 'Correy': 62, 'Li': 38, "O'Tooley": 5}
# 308.0
# ['13718512', 'Marsh', 'Khan']
# Khan
# {'Khan': 203, 'Correy': 62, 'Li': 38, "O'Tooley": 5}
# 309.0
# ['15224490', 'Marsh', 'Khan']
# Khan
# {'Khan': 204, 'Correy': 62, 'Li': 38, "O'Tooley": 5}
# 310.0
# ['16804721', 'Marsh', 'Correy']
# Correy
# {'Khan': 204, 'Correy': 63, 'Li': 38, "O'Tooley": 5}
# 311.0
# ['16998659', 'Marsh', 'Khan']
# Khan
# {'Khan': 205, 'Correy': 63, 'Li': 38, "O'Tooley": 5}
# 312.0
# ['18955053', 'Marsh', 'Khan']
# Khan
# {'Khan': 206, 'Correy': 63, 'Li': 38, "O'Tooley": 5}
# 313.0
# ['14645617', 'Marsh', 'Correy']
# Correy
# {'Khan': 206, 'Correy': 64, 'Li': 38, "O'Tooley": 5}
# 314.0
# ['13823623', 'Marsh', 'Khan']
# Khan
# {'Khan': 207, 'Correy': 64, 'Li': 38, "O'Tooley": 5}
# 315.0
# ['19174372', 'Marsh', 'Khan']
# Khan
# {'Khan': 208, 'Correy': 64, 'Li': 38, "O'Tooley": 5}
# 316.0
# ['11547174', 'Queen', 'Correy']
# Correy
# {'Khan': 208, 'Correy': 65, 'Li': 38, "O'Tooley": 5}
# 317.0
# ['14387134', 'Marsh', 'Khan']
# Khan
# {'Khan': 209, 'Correy': 65, 'Li': 38, "O'Tooley": 5}
# 318.0
# ['19442995', 'Marsh', 'Correy']
# Correy
# {'Khan': 209, 'Correy': 66, 'Li': 38, "O'Tooley": 5}
# 319.0
# ['18575480', 'Marsh', 'Li']
# Li
# {'Khan': 209, 'Correy': 66, 'Li': 39, "O'Tooley": 5}
# 320.0
# ['19226746', 'Marsh', 'Li']
# Li
# {'Khan': 209, 'Correy': 66, 'Li': 40, "O'Tooley": 5}
# 321.0
# ['13603146', 'Bamoo', 'Khan']
# Khan
# {'Khan': 210, 'Correy': 66, 'Li': 40, "O'Tooley": 5}
# 322.0
# ['13123161', 'Marsh', 'Khan']
# Khan
# {'Khan': 211, 'Correy': 66, 'Li': 40, "O'Tooley": 5}
# 323.0
# ['14855837', 'Marsh', 'Correy']
# Correy
# {'Khan': 211, 'Correy': 67, 'Li': 40, "O'Tooley": 5}
# 324.0
# ['10591199', 'Bamoo', 'Khan']
# Khan
# {'Khan': 212, 'Correy': 67, 'Li': 40, "O'Tooley": 5}
# 325.0
# ['15196376', 'Marsh', 'Khan']
# Khan
# {'Khan': 213, 'Correy': 67, 'Li': 40, "O'Tooley": 5}
# 326.0
# ['15141542', 'Marsh', 'Khan']
# Khan
# {'Khan': 214, 'Correy': 67, 'Li': 40, "O'Tooley": 5}
# 327.0
# ['14872905', 'Marsh', 'Khan']
# Khan
# {'Khan': 215, 'Correy': 67, 'Li': 40, "O'Tooley": 5}
# 328.0
# ['10524917', 'Marsh', 'Correy']
# Correy
# {'Khan': 215, 'Correy': 68, 'Li': 40, "O'Tooley": 5}
# 329.0
# ['10874538', 'Queen', 'Correy']
# Correy
# {'Khan': 215, 'Correy': 69, 'Li': 40, "O'Tooley": 5}
# 330.0
# ['18567371', 'Marsh', 'Khan']
# Khan
# {'Khan': 216, 'Correy': 69, 'Li': 40, "O'Tooley": 5}
# 331.0
# ['10761508', 'Marsh', 'Khan']
# Khan
# {'Khan': 217, 'Correy': 69, 'Li': 40, "O'Tooley": 5}
# 332.0
# ['12093324', 'Queen', 'Khan']
# Khan
# {'Khan': 218, 'Correy': 69, 'Li': 40, "O'Tooley": 5}
# 333.0
# ['15978581', 'Marsh', 'Khan']
# Khan
# {'Khan': 219, 'Correy': 69, 'Li': 40, "O'Tooley": 5}
# 334.0
# ['15124244', 'Marsh', 'Khan']
# Khan
# {'Khan': 220, 'Correy': 69, 'Li': 40, "O'Tooley": 5}
# 335.0
# ['12299282', 'Marsh', 'Khan']
# Khan
# {'Khan': 221, 'Correy': 69, 'Li': 40, "O'Tooley": 5}
# 336.0
# ['19261356', 'Bamoo', 'Khan']
# Khan
# {'Khan': 222, 'Correy': 69, 'Li': 40, "O'Tooley": 5}
# 337.0
# ['11978032', 'Bamoo', 'Khan']
# Khan
# {'Khan': 223, 'Correy': 69, 'Li': 40, "O'Tooley": 5}
# 338.0
# ['18371513', 'Trandee', 'Khan']
# Khan
# {'Khan': 224, 'Correy': 69, 'Li': 40, "O'Tooley": 5}
# 339.0
# ['10069778', 'Queen', 'Khan']
# Khan
# {'Khan': 225, 'Correy': 69, 'Li': 40, "O'Tooley": 5}
# 340.0
# ['14008206', 'Marsh', 'Li']
# Li
# {'Khan': 225, 'Correy': 69, 'Li': 41, "O'Tooley": 5}
# 341.0
# ['19243304', 'Queen', 'Khan']
# Khan
# {'Khan': 226, 'Correy': 69, 'Li': 41, "O'Tooley": 5}
# 342.0
# ['13295807', 'Marsh', 'Khan']
# Khan
# {'Khan': 227, 'Correy': 69, 'Li': 41, "O'Tooley": 5}
# 343.0
# ['19235053', 'Raffah', 'Khan']
# Khan
# {'Khan': 228, 'Correy': 69, 'Li': 41, "O'Tooley": 5}
# 344.0
# ['11560382', 'Marsh', 'Li']
# Li
# {'Khan': 228, 'Correy': 69, 'Li': 42, "O'Tooley": 5}
# 345.0
# ['16233712', 'Marsh', 'Li']
# Li
# {'Khan': 228, 'Correy': 69, 'Li': 43, "O'Tooley": 5}
# 346.0
# ['12570463', 'Marsh', 'Khan']
# Khan
# {'Khan': 229, 'Correy': 69, 'Li': 43, "O'Tooley": 5}
# 347.0
# ['14415670', 'Marsh', 'Khan']
# Khan
# {'Khan': 230, 'Correy': 69, 'Li': 43, "O'Tooley": 5}
# 348.0
# ['17957021', 'Queen', 'Khan']
# Khan
# {'Khan': 231, 'Correy': 69, 'Li': 43, "O'Tooley": 5}
# 349.0
# ['17582714', 'Queen', 'Khan']
# Khan
# {'Khan': 232, 'Correy': 69, 'Li': 43, "O'Tooley": 5}
# 350.0
# ['19296827', 'Queen', 'Khan']
# Khan
# {'Khan': 233, 'Correy': 69, 'Li': 43, "O'Tooley": 5}
# 351.0
# ['19019799', 'Marsh', 'Correy']
# Correy
# {'Khan': 233, 'Correy': 70, 'Li': 43, "O'Tooley": 5}
# 352.0
# ['13001863', 'Marsh', 'Khan']
# Khan
# {'Khan': 234, 'Correy': 70, 'Li': 43, "O'Tooley": 5}
# 353.0
# ['14947365', 'Bamoo', 'Correy']
# Correy
# {'Khan': 234, 'Correy': 71, 'Li': 43, "O'Tooley": 5}
# 354.0
# ['17863518', 'Queen', 'Correy']
# Correy
# {'Khan': 234, 'Correy': 72, 'Li': 43, "O'Tooley": 5}
# 355.0
# ['12439837', 'Marsh', 'Khan']
# Khan
# {'Khan': 235, 'Correy': 72, 'Li': 43, "O'Tooley": 5}
# 356.0
# ['13661276', 'Marsh', 'Khan']
# Khan
# {'Khan': 236, 'Correy': 72, 'Li': 43, "O'Tooley": 5}
# 357.0
# ['16982513', 'Marsh', 'Khan']
# Khan
# {'Khan': 237, 'Correy': 72, 'Li': 43, "O'Tooley": 5}
# 358.0
# ['16035168', 'Marsh', 'Khan']
# Khan
# {'Khan': 238, 'Correy': 72, 'Li': 43, "O'Tooley": 5}
# 359.0
# ['18643342', 'Queen', 'Li']
# Li
# {'Khan': 238, 'Correy': 72, 'Li': 44, "O'Tooley": 5}
# 360.0
# ['18072810', 'Marsh', 'Khan']
# Khan
# {'Khan': 239, 'Correy': 72, 'Li': 44, "O'Tooley": 5}
# 361.0
# ['17843702', 'Marsh', 'Correy']
# Correy
# {'Khan': 239, 'Correy': 73, 'Li': 44, "O'Tooley": 5}
# 362.0
# ['16400713', 'Marsh', 'Khan']
# Khan
# {'Khan': 240, 'Correy': 73, 'Li': 44, "O'Tooley": 5}
# 363.0
# ['15095735', 'Marsh', 'Khan']
# Khan
# {'Khan': 241, 'Correy': 73, 'Li': 44, "O'Tooley": 5}
# 364.0
# ['14316913', 'Marsh', 'Correy']
# Correy
# {'Khan': 241, 'Correy': 74, 'Li': 44, "O'Tooley": 5}
# 365.0
# ['18308594', 'Queen', 'Khan']
# Khan
# {'Khan': 242, 'Correy': 74, 'Li': 44, "O'Tooley": 5}
# 366.0
# ['18921972', 'Queen', 'Khan']
# Khan
# {'Khan': 243, 'Correy': 74, 'Li': 44, "O'Tooley": 5}
# 367.0
# ['18089746', 'Marsh', 'Correy']
# Correy
# {'Khan': 243, 'Correy': 75, 'Li': 44, "O'Tooley": 5}
# 368.0
# ['15420328', 'Marsh', 'Khan']
# Khan
# {'Khan': 244, 'Correy': 75, 'Li': 44, "O'Tooley": 5}
# 369.0
# ['10622109', 'Queen', 'Correy']
# Correy
# {'Khan': 244, 'Correy': 76, 'Li': 44, "O'Tooley": 5}
# 370.0
# ['10496577', 'Marsh', 'Khan']
# Khan
# {'Khan': 245, 'Correy': 76, 'Li': 44, "O'Tooley": 5}
# 371.0
# ['16137589', 'Marsh', 'Khan']
# Khan
# {'Khan': 246, 'Correy': 76, 'Li': 44, "O'Tooley": 5}
# 372.0
# ['17997787', 'Marsh', 'Khan']
# Khan
# {'Khan': 247, 'Correy': 76, 'Li': 44, "O'Tooley": 5}
# 373.0
# ['11827357', 'Marsh', 'Correy']
# Correy
# {'Khan': 247, 'Correy': 77, 'Li': 44, "O'Tooley": 5}
# 374.0
# ['19728770', 'Marsh', 'Khan']
# Khan
# {'Khan': 248, 'Correy': 77, 'Li': 44, "O'Tooley": 5}
# 375.0
# ['15079288', 'Marsh', 'Li']
# Li
# {'Khan': 248, 'Correy': 77, 'Li': 45, "O'Tooley": 5}
# 376.0
# ['16481625', 'Marsh', 'Khan']
# Khan
# {'Khan': 249, 'Correy': 77, 'Li': 45, "O'Tooley": 5}
# 377.0
# ['18239775', 'Marsh', 'Correy']
# Correy
# {'Khan': 249, 'Correy': 78, 'Li': 45, "O'Tooley": 5}
# 378.0
# ['19942092', 'Marsh', 'Correy']
# Correy
# {'Khan': 249, 'Correy': 79, 'Li': 45, "O'Tooley": 5}
# 379.0
# ['10874676', 'Queen', 'Khan']
# Khan
# {'Khan': 250, 'Correy': 79, 'Li': 45, "O'Tooley": 5}
# 380.0
# ['16033812', 'Marsh', 'Correy']
# Correy
# {'Khan': 250, 'Correy': 80, 'Li': 45, "O'Tooley": 5}
# 381.0
# ['13002390', 'Marsh', 'Li']
# Li
# {'Khan': 250, 'Correy': 80, 'Li': 46, "O'Tooley": 5}
# 382.0
# ['17237880', 'Marsh', "O'Tooley"]
# O'Tooley
# {'Khan': 250, 'Correy': 80, 'Li': 46, "O'Tooley": 6}
# 383.0
# ['10161718', 'Marsh', 'Khan']
# Khan
# {'Khan': 251, 'Correy': 80, 'Li': 46, "O'Tooley": 6}
# 384.0
# ['14230556', 'Marsh', 'Khan']
# Khan
# {'Khan': 252, 'Correy': 80, 'Li': 46, "O'Tooley": 6}
# 385.0
# ['10285316', 'Queen', 'Khan']
# Khan
# {'Khan': 253, 'Correy': 80, 'Li': 46, "O'Tooley": 6}
# 386.0
# ['10761988', 'Marsh', 'Correy']
# Correy
# {'Khan': 253, 'Correy': 81, 'Li': 46, "O'Tooley": 6}
# 387.0
# ['10755669', 'Marsh', 'Khan']
# Khan
# {'Khan': 254, 'Correy': 81, 'Li': 46, "O'Tooley": 6}
# 388.0
# ['18039858', 'Marsh', 'Khan']
# Khan
# {'Khan': 255, 'Correy': 81, 'Li': 46, "O'Tooley": 6}
# 389.0
# ['15011198', 'Queen', 'Khan']
# Khan
# {'Khan': 256, 'Correy': 81, 'Li': 46, "O'Tooley": 6}
# 390.0
# ['17969453', 'Marsh', 'Khan']
# Khan
# {'Khan': 257, 'Correy': 81, 'Li': 46, "O'Tooley": 6}
# 391.0
# ['13104005', 'Queen', 'Correy']
# Correy
# {'Khan': 257, 'Correy': 82, 'Li': 46, "O'Tooley": 6}
# 392.0
# ['11791332', 'Bamoo', 'Khan']
# Khan
# {'Khan': 258, 'Correy': 82, 'Li': 46, "O'Tooley": 6}
# 393.0
# ['18568474', 'Marsh', 'Li']
# Li
# {'Khan': 258, 'Correy': 82, 'Li': 47, "O'Tooley": 6}
# 394.0
# ['19330152', 'Bamoo', 'Li']
# Li
# {'Khan': 258, 'Correy': 82, 'Li': 48, "O'Tooley": 6}
# 395.0
# ['15696423', 'Marsh', "O'Tooley"]
# O'Tooley
# {'Khan': 258, 'Correy': 82, 'Li': 48, "O'Tooley": 7}
# 396.0
# ['17569473', 'Queen', 'Khan']
# Khan
# {'Khan': 259, 'Correy': 82, 'Li': 48, "O'Tooley": 7}
# 397.0
# ['14440979', 'Marsh', 'Li']
# Li
# {'Khan': 259, 'Correy': 82, 'Li': 49, "O'Tooley": 7}
# 398.0
# ['14072385', 'Marsh', "O'Tooley"]
# O'Tooley
# {'Khan': 259, 'Correy': 82, 'Li': 49, "O'Tooley": 8}
# 399.0
# ['18494846', 'Queen', 'Khan']
# Khan
# {'Khan': 260, 'Correy': 82, 'Li': 49, "O'Tooley": 8}
# 400.0
# ['16975409', 'Marsh', 'Khan']
# Khan
# {'Khan': 261, 'Correy': 82, 'Li': 49, "O'Tooley": 8}
# 401.0
# ['11033927', 'Queen', 'Correy']
# Correy
# {'Khan': 261, 'Correy': 83, 'Li': 49, "O'Tooley": 8}
# 402.0
# ['11704946', 'Marsh', 'Khan']
# Khan
# {'Khan': 262, 'Correy': 83, 'Li': 49, "O'Tooley": 8}
# 403.0
# ['17780413', 'Marsh', 'Khan']
# Khan
# {'Khan': 263, 'Correy': 83, 'Li': 49, "O'Tooley": 8}
# 404.0
# ['16452334', 'Bamoo', 'Khan']
# Khan
# {'Khan': 264, 'Correy': 83, 'Li': 49, "O'Tooley": 8}
# 405.0
# ['16995693', 'Marsh', 'Correy']
# Correy
# {'Khan': 264, 'Correy': 84, 'Li': 49, "O'Tooley": 8}
# 406.0
# ['19359036', 'Marsh', 'Khan']
# Khan
# {'Khan': 265, 'Correy': 84, 'Li': 49, "O'Tooley": 8}
# 407.0
# ['18594851', 'Marsh', 'Correy']
# Correy
# {'Khan': 265, 'Correy': 85, 'Li': 49, "O'Tooley": 8}
# 408.0
# ['10695663', 'Queen', 'Khan']
# Khan
# {'Khan': 266, 'Correy': 85, 'Li': 49, "O'Tooley": 8}
# 409.0
# ['10971291', 'Marsh', 'Correy']
# Correy
# {'Khan': 266, 'Correy': 86, 'Li': 49, "O'Tooley": 8}
# 410.0
# ['15943195', 'Marsh', 'Khan']
# Khan
# {'Khan': 267, 'Correy': 86, 'Li': 49, "O'Tooley": 8}
# 411.0
# ['18296399', 'Marsh', 'Correy']
# Correy
# {'Khan': 267, 'Correy': 87, 'Li': 49, "O'Tooley": 8}
# 412.0
# ['16324747', 'Queen', 'Correy']
# Correy
# {'Khan': 267, 'Correy': 88, 'Li': 49, "O'Tooley": 8}
# 413.0
# ['12966021', 'Marsh', 'Li']
# Li
# {'Khan': 267, 'Correy': 88, 'Li': 50, "O'Tooley": 8}
# 414.0
# ['18180173', 'Marsh', 'Khan']
# Khan
# {'Khan': 268, 'Correy': 88, 'Li': 50, "O'Tooley": 8}
# 415.0
# ['14850725', 'Marsh', 'Khan']
# Khan
# {'Khan': 269, 'Correy': 88, 'Li': 50, "O'Tooley": 8}
# 416.0
# ['14042487', 'Marsh', 'Khan']
# Khan
# {'Khan': 270, 'Correy': 88, 'Li': 50, "O'Tooley": 8}
# 417.0
# ['17685242', 'Marsh', 'Li']
# Li
# {'Khan': 270, 'Correy': 88, 'Li': 51, "O'Tooley": 8}
# 418.0
# ['17829591', 'Bamoo', 'Khan']
# Khan
# {'Khan': 271, 'Correy': 88, 'Li': 51, "O'Tooley": 8}
# 419.0
# ['17358700', 'Marsh', 'Correy']
# Correy
# {'Khan': 271, 'Correy': 89, 'Li': 51, "O'Tooley": 8}
# 420.0
# ['11789614', 'Marsh', 'Correy']
# Correy
# {'Khan': 271, 'Correy': 90, 'Li': 51, "O'Tooley": 8}
# 421.0
# ['17827030', 'Marsh', 'Khan']
# Khan
# {'Khan': 272, 'Correy': 90, 'Li': 51, "O'Tooley": 8}
# 422.0
# ['14196508', 'Marsh', 'Khan']
# Khan
# {'Khan': 273, 'Correy': 90, 'Li': 51, "O'Tooley": 8}
# 423.0
# ['19686261', 'Marsh', 'Khan']
# Khan
# {'Khan': 274, 'Correy': 90, 'Li': 51, "O'Tooley": 8}
# 424.0
# ['11674532', 'Queen', 'Correy']
# Correy
# {'Khan': 274, 'Correy': 91, 'Li': 51, "O'Tooley": 8}
# 425.0
# ['10678939', 'Trandee', 'Khan']
# Khan
# {'Khan': 275, 'Correy': 91, 'Li': 51, "O'Tooley": 8}
# 426.0
# ['19276395', 'Marsh', 'Khan']
# Khan
# {'Khan': 276, 'Correy': 91, 'Li': 51, "O'Tooley": 8}
# 427.0
# ['11012166', 'Marsh', 'Correy']
# Correy
# {'Khan': 276, 'Correy': 92, 'Li': 51, "O'Tooley": 8}
# 428.0
# ['17682973', 'Marsh', 'Correy']
# Correy
# {'Khan': 276, 'Correy': 93, 'Li': 51, "O'Tooley": 8}
# 429.0
# ['18694752', 'Marsh', 'Khan']
# Khan
# {'Khan': 277, 'Correy': 93, 'Li': 51, "O'Tooley": 8}
# 430.0
# ['19513797', 'Marsh', 'Correy']
# Correy
# {'Khan': 277, 'Correy': 94, 'Li': 51, "O'Tooley": 8}
# 431.0
# ['16122321', 'Trandee', 'Khan']
# Khan
# {'Khan': 278, 'Correy': 94, 'Li': 51, "O'Tooley": 8}
# 432.0
# ['10279616', 'Marsh', 'Khan']
# Khan
# {'Khan': 279, 'Correy': 94, 'Li': 51, "O'Tooley": 8}
# 433.0
# ['19279895', 'Queen', 'Correy']
# Correy
# {'Khan': 279, 'Correy': 95, 'Li': 51, "O'Tooley": 8}
# 434.0
# ['14771731', 'Marsh', 'Correy']
# Correy
# {'Khan': 279, 'Correy': 96, 'Li': 51, "O'Tooley": 8}
# 435.0
# ['18585531', 'Marsh', 'Khan']
# Khan
# {'Khan': 280, 'Correy': 96, 'Li': 51, "O'Tooley": 8}
# 436.0
# ['17001617', 'Trandee', 'Correy']
# Correy
# {'Khan': 280, 'Correy': 97, 'Li': 51, "O'Tooley": 8}
# 437.0
# ['15551187', 'Marsh', "O'Tooley"]
# O'Tooley
# {'Khan': 280, 'Correy': 97, 'Li': 51, "O'Tooley": 9}
# 438.0
# ['16702982', 'Marsh', 'Khan']
# Khan
# {'Khan': 281, 'Correy': 97, 'Li': 51, "O'Tooley": 9}
# 439.0
# ['13030884', 'Marsh', 'Khan']
# Khan
# {'Khan': 282, 'Correy': 97, 'Li': 51, "O'Tooley": 9}
# 440.0
# ['11367757', 'Queen', 'Khan']
# Khan
# {'Khan': 283, 'Correy': 97, 'Li': 51, "O'Tooley": 9}
# 441.0
# ['16471021', 'Marsh', 'Khan']
# Khan
# {'Khan': 284, 'Correy': 97, 'Li': 51, "O'Tooley": 9}
# 442.0
# ['13300333', 'Queen', 'Correy']
# Correy
# {'Khan': 284, 'Correy': 98, 'Li': 51, "O'Tooley": 9}
# 443.0
# ['19354176', 'Queen', 'Khan']
# Khan
# {'Khan': 285, 'Correy': 98, 'Li': 51, "O'Tooley": 9}
# 444.0
# ['14708118', 'Marsh', 'Khan']
# Khan
# {'Khan': 286, 'Correy': 98, 'Li': 51, "O'Tooley": 9}
# 445.0
# ['15894675', 'Marsh', 'Correy']
# Correy
# {'Khan': 286, 'Correy': 99, 'Li': 51, "O'Tooley": 9}
# 446.0
# ['11774294', 'Marsh', 'Khan']
# Khan
# {'Khan': 287, 'Correy': 99, 'Li': 51, "O'Tooley": 9}
# 447.0
# ['17811102', 'Bamoo', 'Khan']
# Khan
# {'Khan': 288, 'Correy': 99, 'Li': 51, "O'Tooley": 9}
# 448.0
# ['14317449', 'Marsh', 'Correy']
# Correy
# {'Khan': 288, 'Correy': 100, 'Li': 51, "O'Tooley": 9}
# 449.0
# ['15007777', 'Queen', 'Li']
# Li
# {'Khan': 288, 'Correy': 100, 'Li': 52, "O'Tooley": 9}
# 450.0
# ['11438450', 'Marsh', 'Khan']
# Khan
# {'Khan': 289, 'Correy': 100, 'Li': 52, "O'Tooley": 9}
# 451.0
# ['17966042', 'Marsh', 'Correy']
# Correy
# {'Khan': 289, 'Correy': 101, 'Li': 52, "O'Tooley": 9}
# 452.0
# ['18422779', 'Queen', 'Khan']
# Khan
# {'Khan': 290, 'Correy': 101, 'Li': 52, "O'Tooley": 9}
# 453.0
# ['16780696', 'Marsh', 'Khan']
# Khan
# {'Khan': 291, 'Correy': 101, 'Li': 52, "O'Tooley": 9}
# 454.0
# ['14597057', 'Marsh', 'Khan']
# Khan
# {'Khan': 292, 'Correy': 101, 'Li': 52, "O'Tooley": 9}
# 455.0
# ['17661568', 'Marsh', 'Correy']
# Correy
# {'Khan': 292, 'Correy': 102, 'Li': 52, "O'Tooley": 9}
# 456.0
# ['10095393', 'Bamoo', 'Khan']
# Khan
# {'Khan': 293, 'Correy': 102, 'Li': 52, "O'Tooley": 9}
# 457.0
# ['11136296', 'Marsh', 'Correy']
# Correy
# {'Khan': 293, 'Correy': 103, 'Li': 52, "O'Tooley": 9}
# 458.0
# ['17125335', 'Queen', 'Khan']
# Khan
# {'Khan': 294, 'Correy': 103, 'Li': 52, "O'Tooley": 9}
# 459.0
# ['19839618', 'Marsh', 'Khan']
# Khan
# {'Khan': 295, 'Correy': 103, 'Li': 52, "O'Tooley": 9}
# 460.0
# ['17334934', 'Marsh', 'Correy']
# Correy
# {'Khan': 295, 'Correy': 104, 'Li': 52, "O'Tooley": 9}
# 461.0
# ['12387416', 'Bamoo', 'Khan']
# Khan
# {'Khan': 296, 'Correy': 104, 'Li': 52, "O'Tooley": 9}
# 462.0
# ['15088978', 'Queen', 'Khan']
# Khan
# {'Khan': 297, 'Correy': 104, 'Li': 52, "O'Tooley": 9}
# 463.0
# ['12518350', 'Queen', 'Khan']
# Khan
# {'Khan': 298, 'Correy': 104, 'Li': 52, "O'Tooley": 9}
# 464.0
# ['19876290', 'Bamoo', 'Khan']
# Khan
# {'Khan': 299, 'Correy': 104, 'Li': 52, "O'Tooley": 9}
# 465.0
# ['12640974', 'Marsh', 'Khan']
# Khan
# {'Khan': 300, 'Correy': 104, 'Li': 52, "O'Tooley": 9}
# 466.0
# ['18174536', 'Bamoo', 'Khan']
# Khan
# {'Khan': 301, 'Correy': 104, 'Li': 52, "O'Tooley": 9}
# 467.0
# ['11999576', 'Marsh', 'Khan']
# Khan
# {'Khan': 302, 'Correy': 104, 'Li': 52, "O'Tooley": 9}
# 468.0
# ['17725436', 'Queen', 'Correy']
# Correy
# {'Khan': 302, 'Correy': 105, 'Li': 52, "O'Tooley": 9}
# 469.0
# ['18664235', 'Marsh', 'Correy']
# Correy
# {'Khan': 302, 'Correy': 106, 'Li': 52, "O'Tooley": 9}
# 470.0
# ['19121053', 'Marsh', 'Correy']
# Correy
# {'Khan': 302, 'Correy': 107, 'Li': 52, "O'Tooley": 9}
# 471.0
# ['16548121', 'Marsh', 'Khan']
# Khan
# {'Khan': 303, 'Correy': 107, 'Li': 52, "O'Tooley": 9}
# 472.0
# ['12689660', 'Marsh', 'Khan']
# Khan
# {'Khan': 304, 'Correy': 107, 'Li': 52, "O'Tooley": 9}
# 473.0
# ['12244860', 'Bamoo', 'Khan']
# Khan
# {'Khan': 305, 'Correy': 107, 'Li': 52, "O'Tooley": 9}
# 474.0
# ['14508578', 'Marsh', 'Khan']
# Khan
# {'Khan': 306, 'Correy': 107, 'Li': 52, "O'Tooley": 9}
# 475.0
# ['11628659', 'Marsh', 'Correy']
# Correy
# {'Khan': 306, 'Correy': 108, 'Li': 52, "O'Tooley": 9}
# 476.0
# ['12721201', 'Marsh', 'Khan']
# Khan
# {'Khan': 307, 'Correy': 108, 'Li': 52, "O'Tooley": 9}
# 477.0
# ['11112027', 'Queen', 'Khan']
# Khan
# {'Khan': 308, 'Correy': 108, 'Li': 52, "O'Tooley": 9}
# 478.0
# ['14451977', 'Marsh', 'Correy']
# Correy
# {'Khan': 308, 'Correy': 109, 'Li': 52, "O'Tooley": 9}
# 479.0
# ['12024673', 'Marsh', 'Correy']
# Correy
# {'Khan': 308, 'Correy': 110, 'Li': 52, "O'Tooley": 9}
# 480.0
# ['14655094', 'Queen', 'Khan']
# Khan
# {'Khan': 309, 'Correy': 110, 'Li': 52, "O'Tooley": 9}
# 481.0
# ['13051885', 'Marsh', 'Khan']
# Khan
# {'Khan': 310, 'Correy': 110, 'Li': 52, "O'Tooley": 9}
# 482.0
# ['17797824', 'Raffah', 'Correy']
# Correy
# {'Khan': 310, 'Correy': 111, 'Li': 52, "O'Tooley": 9}
# 483.0
# ['15873936', 'Marsh', 'Correy']
# Correy
# {'Khan': 310, 'Correy': 112, 'Li': 52, "O'Tooley": 9}
# 484.0
# ['10918311', 'Marsh', 'Khan']
# Khan
# {'Khan': 311, 'Correy': 112, 'Li': 52, "O'Tooley": 9}
# 485.0
# ['12362095', 'Marsh', 'Khan']
# Khan
# {'Khan': 312, 'Correy': 112, 'Li': 52, "O'Tooley": 9}
# 486.0
# ['10581530', 'Marsh', 'Khan']
# Khan
# {'Khan': 313, 'Correy': 112, 'Li': 52, "O'Tooley": 9}
# 487.0
# ['15786902', 'Queen', 'Khan']
# Khan
# {'Khan': 314, 'Correy': 112, 'Li': 52, "O'Tooley": 9}
# 488.0
# ['15804729', 'Marsh', 'Khan']
# Khan
# {'Khan': 315, 'Correy': 112, 'Li': 52, "O'Tooley": 9}
# 489.0
# ['19533695', 'Queen', 'Khan']
# Khan
# {'Khan': 316, 'Correy': 112, 'Li': 52, "O'Tooley": 9}
# 490.0
# ['12095988', 'Marsh', 'Khan']
# Khan
# {'Khan': 317, 'Correy': 112, 'Li': 52, "O'Tooley": 9}
# 491.0
# ['14001599', 'Marsh', 'Li']
# Li
# {'Khan': 317, 'Correy': 112, 'Li': 53, "O'Tooley": 9}
# 492.0
# ['11217298', 'Raffah', 'Khan']
# Khan
# {'Khan': 318, 'Correy': 112, 'Li': 53, "O'Tooley": 9}
# 493.0
# ['15938791', 'Marsh', 'Khan']
# Khan
# {'Khan': 319, 'Correy': 112, 'Li': 53, "O'Tooley": 9}
# 494.0
# ['18366259', 'Queen', 'Li']
# Li
# {'Khan': 319, 'Correy': 112, 'Li': 54, "O'Tooley": 9}
# 495.0
# ['19236465', 'Marsh', 'Correy']
# Correy
# {'Khan': 319, 'Correy': 113, 'Li': 54, "O'Tooley": 9}
# 496.0
# ['18679724', 'Marsh', 'Khan']
# Khan
# {'Khan': 320, 'Correy': 113, 'Li': 54, "O'Tooley": 9}
# 497.0
# ['18773665', 'Marsh', 'Li']
# Li
# {'Khan': 320, 'Correy': 113, 'Li': 55, "O'Tooley": 9}
# 498.0
# ['14694068', 'Raffah', 'Khan']
# Khan
# {'Khan': 321, 'Correy': 113, 'Li': 55, "O'Tooley": 9}
# 499.0
# ['15048762', 'Marsh', 'Khan']
# Khan
# {'Khan': 322, 'Correy': 113, 'Li': 55, "O'Tooley": 9}
# ['Khan', 'Correy', 'Li', "O'Tooley"]
# {'Khan': 322, 'Correy': 113, 'Li': 55, "O'Tooley": 9}
#
#
# Election Results
# -------------------------
# Total Votes: 499
# -------------------------
# 322
# Khan: 64.529% (322)
# 113
# Correy: 22.645% (113)
# 55
# Li: 11.022% (55)
# 9
# O'Tooley: 1.804% (9)
